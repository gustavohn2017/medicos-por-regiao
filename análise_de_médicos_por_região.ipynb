# %%
import pandas as pd
low_memory=False
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'C:/Users/Gustavo/Desktop/EPLBD/medicos1.csv'
df = pd.read_csv(filename, delimiter=',', 
                 encoding='UTF8',
                 error_bad_lines=False)

# %%
''' Análise feita por Gustavo Henrique Nascimento
    Esta análise tem como principal objetivo fazer um comparativo sobre a proporção de médicos ativos nas regiões do Brasil.
    Os dados desta análise foram retirados do portal do CFM (link "http://portal.cfm.org.br/index.php?option=com_estatistica&buscarPor=R&ufEstatistica=&regiaoEstatistica=S&situacaoEstatistica=A&detalheSituacaoEstatistica=&sexoEstatistica=")
    e foram atualizados no dia 03/07/2020
    
    Análise baseada no 
    
    '''
# Out:
# ' Análise feita por Gustavo Henrique Nascimento\n    Esta análise tem como principal objetivo fazer um comparativo sobre a proporção de médicos ativos nas regiões do Brasil.\n    Os dados desta análise foram retirados do portal do CFM (link "http://portal.cfm.org.br/index.php?option=com_estatistica&buscarPor=R&ufEstatistica=&regiaoEstatistica=S&situacaoEstatistica=A&detalheSituacaoEstatistica=&sexoEstatistica=")\n    e foram atualizados no dia 03/07/2020\n    \n    Análise baseada no \n    \n    '

# %%
df.shape
# Out:
# (27, 7)

# %%
for par in enumerate(df.columns): print (par)
# Out:
# (0, 'Região')
# (1, 'UF')
# (2, 'Capital')
# (3, 'Interior')
# (4, 'Outros Estados')
# (5, 'Desatualizado')
# (6, 'Total')

# %%
df.sample(7)
# Out:
#           Região  UF  Capital  Interior  Outros Estados  Desatualizado  Total
# 15         Norte  AP      675        43              34              6    758
# 14         Norte  AM     4713       254             151              8   5126
# 25           Sul  RS    14338     16764             791            625  32518
# 13         Norte  AC      696       188              42              7    933
# 21       Sudeste  MG    19878     33179            1230             79  54366
# 1   Centro-Oeste  GO    11046      5735            2592           1209  20582
# 24           Sul  PR    11835     13751            1022            571  27179

# %%
df.head(27)
# Out:
#           Região  UF  Capital  Interior  Outros Estados  Desatualizado   Total
# 0   Centro-Oeste  DF    17121        13            3340           2195   22669
# 1   Centro-Oeste  GO    11046      5735            2592           1209   20582
# 2   Centro-Oeste  MT     3673      3438            1676            179    8966
# 3   Centro-Oeste  MS     5118      3530             744             21    9413
# 4       Nordeste  AL     4060       706             126            140    5032
# 5       Nordeste  BA    13388      8655             802             22   22867
# 6       Nordeste  CE    10981      3573             246             13   14813
# 7       Nordeste  MA     4008      1694             288             26    6016
# 8       Nordeste  PB     4351      2611             272            128    7362
# 9       Nordeste  PE    12148      4339            1023            300   17810
# 10      Nordeste  PI     3929       925             107              2    4963
# 11      Nordeste  RN     4299      1497             229             62    6087
# 12      Nordeste  SE     3675       293              71             79    4118
# 13         Norte  AC      696       188              42              7     933
# 14         Norte  AM     4713       254             151              8    5126
# 15         Norte  AP      675        43              34              6     758
# 16         Norte  PA     5961      2222             219             65    8467
# 17         Norte  RO     1469      1156             105              4    2734
# 18         Norte  RR      761        21              45              3     830
# 19         Norte  TO     1093      1187             190             60    2530
# 20       Sudeste  ES     4666      5454             221             16   10357
# 21       Sudeste  MG    19878     33179            1230             79   54366
# 22       Sudeste  RJ    36351     19264            1583           7193   64391
# 23       Sudeste  SP    60130     67427            6563           7589  141709
# 24           Sul  PR    11835     13751            1022            571   27179
# 25           Sul  RS    14338     16764             791            625   32518
# 26           Sul  SC     4143     11577             801             63   16584

# %%
ax = df [['Capital','Região']].plot(figsize=(10,10), kind='barh')
ax.set_yticklabels(df['UF'])
# Out:
# [Text(0, 0, 'DF'),
#  Text(0, 0, 'GO'),
#  Text(0, 0, 'MT'),
#  Text(0, 0, 'MS'),
#  Text(0, 0, 'AL'),
#  Text(0, 0, 'BA'),
#  Text(0, 0, 'CE'),
#  Text(0, 0, 'MA'),
#  Text(0, 0, 'PB'),
#  Text(0, 0, 'PE'),
#  Text(0, 0, 'PI'),
#  Text(0, 0, 'RN'),
#  Text(0, 0, 'SE'),
#  Text(0, 0, 'AC'),
#  Text(0, 0, 'AM'),
#  Text(0, 0, 'AP'),
#  Text(0, 0, 'PA'),
#  Text(0, 0, 'RO'),
#  Text(0, 0, 'RR'),
#  Text(0, 0, 'TO'),
#  Text(0, 0, 'ES'),
#  Text(0, 0, 'MG'),
#  Text(0, 0, 'RJ'),
#  Text(0, 0, 'SP'),
#  Text(0, 0, 'PR'),
#  Text(0, 0, 'RS'),
#  Text(0, 0, 'SC')]

# %%
ax = df [['Interior','Região']].plot(figsize=(10,10), kind='barh')
ax.set_yticklabels(df['UF'])
# Out:
# [Text(0, 0, 'DF'),
#  Text(0, 0, 'GO'),
#  Text(0, 0, 'MT'),
#  Text(0, 0, 'MS'),
#  Text(0, 0, 'AL'),
#  Text(0, 0, 'BA'),
#  Text(0, 0, 'CE'),
#  Text(0, 0, 'MA'),
#  Text(0, 0, 'PB'),
#  Text(0, 0, 'PE'),
#  Text(0, 0, 'PI'),
#  Text(0, 0, 'RN'),
#  Text(0, 0, 'SE'),
#  Text(0, 0, 'AC'),
#  Text(0, 0, 'AM'),
#  Text(0, 0, 'AP'),
#  Text(0, 0, 'PA'),
#  Text(0, 0, 'RO'),
#  Text(0, 0, 'RR'),
#  Text(0, 0, 'TO'),
#  Text(0, 0, 'ES'),
#  Text(0, 0, 'MG'),
#  Text(0, 0, 'RJ'),
#  Text(0, 0, 'SP'),
#  Text(0, 0, 'PR'),
#  Text(0, 0, 'RS'),
#  Text(0, 0, 'SC')]

# %%
ax = df [['Total','Região']].plot(figsize=(10,10), kind='barh')
ax.set_yticklabels(df['UF'])
# Out:
# [Text(0, 0, 'DF'),
#  Text(0, 0, 'GO'),
#  Text(0, 0, 'MT'),
#  Text(0, 0, 'MS'),
#  Text(0, 0, 'AL'),
#  Text(0, 0, 'BA'),
#  Text(0, 0, 'CE'),
#  Text(0, 0, 'MA'),
#  Text(0, 0, 'PB'),
#  Text(0, 0, 'PE'),
#  Text(0, 0, 'PI'),
#  Text(0, 0, 'RN'),
#  Text(0, 0, 'SE'),
#  Text(0, 0, 'AC'),
#  Text(0, 0, 'AM'),
#  Text(0, 0, 'AP'),
#  Text(0, 0, 'PA'),
#  Text(0, 0, 'RO'),
#  Text(0, 0, 'RR'),
#  Text(0, 0, 'TO'),
#  Text(0, 0, 'ES'),
#  Text(0, 0, 'MG'),
#  Text(0, 0, 'RJ'),
#  Text(0, 0, 'SP'),
#  Text(0, 0, 'PR'),
#  Text(0, 0, 'RS'),
#  Text(0, 0, 'SC')]
